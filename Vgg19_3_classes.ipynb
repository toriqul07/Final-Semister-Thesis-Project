# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
from keras.applications.mobilenet import MobileNet
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import argparse


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)

        img = cv2.imread(PATH)

        img = cv2.resize(img, (RESIZE,RESIZE))

        IMG.append(np.array(img))
    return IMG

# %%
#load data
early_blight_norm_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/EarlyBlight_Normal',224))
#early_blight_serious_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/EarlyBlight_Serious',224))
late_blight_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/LateBlight',224))
healthy_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Healthy',224))
#insect_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Insect',224))
#lrv_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/LeafRoll',224))
#virus_train =np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Virus',224))

early_blight_norm_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/EarlyBlight_Normal',224))
#early_blight_serious_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/EarlyBlight_Serious',224))
late_blight_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/LateBlight',224))
healthy_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Healthy',224))
#insect_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Insect',224))
#lrv_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/LeafRoll',224))
#virus_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Virus',224))
# Out:
# 100%|██████████| 800/800 [00:15<00:00, 52.13it/s]
# 100%|██████████| 800/800 [00:10<00:00, 72.74it/s]
# 100%|██████████| 800/800 [00:09<00:00, 85.36it/s]
# 100%|██████████| 206/206 [00:02<00:00, 90.57it/s]
# 100%|██████████| 200/200 [00:02<00:00, 81.12it/s]
# 100%|██████████| 205/205 [00:05<00:00, 34.48it/s]

# %%
# Create labels
early_blight_norm_train_label = np.full(len(early_blight_norm_train),0)
#early_blight_serious_train_label = np.full(len(early_blight_serious_train),1)
late_blight_train_label = np.full(len(late_blight_train),1)
healthy_train_label = np.full(len(healthy_train),2)
#insect_train_label = np.full(len(insect_train),4)
#lrv_train_label = np.full(len(lrv_train),5)
#virus_train_label = np.full(len(virus_train),6)

early_blight_norm_test_label = np.full(len(early_blight_norm_test),0)
#early_blight_serious_test_label = np.full(len(early_blight_serious_test),1)
late_blight_test_label = np.full(len(late_blight_test),1)
healthy_test_label = np.full(len(healthy_test),2)
#insect_test_label = np.full(len(insect_test),4)
#lrv_test_label = np.full(len(lrv_test),5)
#virus_test_label = np.full(len(virus_test),6)

# %%
# Merge data
X_train = np.concatenate((early_blight_norm_train, late_blight_train, healthy_train), axis = 0)
Y_train = np.concatenate((early_blight_norm_train_label, late_blight_train_label, healthy_train_label), axis = 0)
X_test = np.concatenate((early_blight_norm_test, late_blight_test, healthy_test), axis = 0)
Y_test = np.concatenate((early_blight_norm_test_label, late_blight_test_label, healthy_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 3)
Y_test = to_categorical(Y_test, num_classes= 3)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train,
    test_size=0.2,
    random_state=11
)

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.4,
        height_shift_range=0.4,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images

    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)

vgg19      = VGG19(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
outputs = Concatenate(axis=-1)([GlobalAveragePooling2D()(vgg19)])
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs)
outputs = Dense(128,activation='relu')(outputs)
outputs = Dropout(0.2)(outputs)
outputs = BatchNormalization()(outputs)
outputs = Dense(3, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  concatenate (Concatenate)   (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 20092995 (76.65 MB)
# Trainable params: 20091715 (76.64 MB)
# Non-trainable params: 1280 (5.00 KB)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/My Drive/Vgg19(3_classes).hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# Epoch 1/50
# 60/60 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.5052
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 66s 625ms/step - loss: 0.7094 - accuracy: 0.5052 - val_loss: 0.8199 - val_accuracy: 0.6729 - lr: 1.0000e-04
# Epoch 2/50
# 60/60 [==============================] - ETA: 0s - loss: 0.4902 - accuracy: 0.6964
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 673ms/step - loss: 0.4902 - accuracy: 0.6964 - val_loss: 0.4449 - val_accuracy: 0.8896 - lr: 1.0000e-04
# Epoch 3/50
# 60/60 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.7641
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 696ms/step - loss: 0.4282 - accuracy: 0.7641 - val_loss: 0.6303 - val_accuracy: 0.6792 - lr: 1.0000e-04
# Epoch 4/50
# 60/60 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.8073
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 657ms/step - loss: 0.3762 - accuracy: 0.8073 - val_loss: 0.2755 - val_accuracy: 0.8479 - lr: 1.0000e-04
# Epoch 5/50
# 60/60 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.8859
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 667ms/step - loss: 0.2666 - accuracy: 0.8859 - val_loss: 0.1363 - val_accuracy: 0.9708 - lr: 1.0000e-04
# Epoch 6/50
# 60/60 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8786
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 672ms/step - loss: 0.2663 - accuracy: 0.8786 - val_loss: 0.3834 - val_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 7/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9187
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 658ms/step - loss: 0.1977 - accuracy: 0.9187 - val_loss: 0.2284 - val_accuracy: 0.9417 - lr: 1.0000e-04
# Epoch 8/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9323
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 680ms/step - loss: 0.1567 - accuracy: 0.9323 - val_loss: 0.0824 - val_accuracy: 0.9646 - lr: 1.0000e-04
# Epoch 9/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9401
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 667ms/step - loss: 0.1361 - accuracy: 0.9401 - val_loss: 0.0412 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 10/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.9505
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 682ms/step - loss: 0.1222 - accuracy: 0.9505 - val_loss: 0.0775 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 11/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9505
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 705ms/step - loss: 0.1170 - accuracy: 0.9505 - val_loss: 0.0348 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 12/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9578
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 665ms/step - loss: 0.1087 - accuracy: 0.9578 - val_loss: 0.0456 - val_accuracy: 0.9854 - lr: 1.0000e-04
# Epoch 13/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9505
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 674ms/step - loss: 0.1098 - accuracy: 0.9505 - val_loss: 0.0331 - val_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 14/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9438
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 671ms/step - loss: 0.1254 - accuracy: 0.9438 - val_loss: 0.0404 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 15/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9542
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 653ms/step - loss: 0.1049 - accuracy: 0.9542 - val_loss: 0.0568 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 16/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9510
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 694ms/step - loss: 0.1079 - accuracy: 0.9510 - val_loss: 0.1687 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 17/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9552
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 688ms/step - loss: 0.0979 - accuracy: 0.9552 - val_loss: 0.0309 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 18/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9771
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 679ms/step - loss: 0.0673 - accuracy: 0.9771 - val_loss: 0.0241 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 19/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9578
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 659ms/step - loss: 0.0858 - accuracy: 0.9578 - val_loss: 0.0276 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 20/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 682ms/step - loss: 0.0780 - accuracy: 0.9656 - val_loss: 0.0194 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 21/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9583
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 693ms/step - loss: 0.0835 - accuracy: 0.9583 - val_loss: 0.0559 - val_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 22/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9594
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 705ms/step - loss: 0.0890 - accuracy: 0.9594 - val_loss: 0.0325 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 23/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9651
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 650ms/step - loss: 0.0764 - accuracy: 0.9651 - val_loss: 0.0143 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 24/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9755
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 683ms/step - loss: 0.0643 - accuracy: 0.9755 - val_loss: 0.1001 - val_accuracy: 0.9458 - lr: 1.0000e-04
# Epoch 25/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 685ms/step - loss: 0.0785 - accuracy: 0.9656 - val_loss: 0.0222 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 26/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9646
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 675ms/step - loss: 0.0861 - accuracy: 0.9646 - val_loss: 0.0154 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 27/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9708
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 677ms/step - loss: 0.0594 - accuracy: 0.9708 - val_loss: 0.0218 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 28/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 44s 732ms/step - loss: 0.0602 - accuracy: 0.9750 - val_loss: 0.0372 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 29/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9646
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 43s 712ms/step - loss: 0.0717 - accuracy: 0.9646 - val_loss: 0.0184 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 30/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9625
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 658ms/step - loss: 0.0779 - accuracy: 0.9625 - val_loss: 0.0133 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 31/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9693
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 680ms/step - loss: 0.0622 - accuracy: 0.9693 - val_loss: 0.0229 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 32/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9714
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 670ms/step - loss: 0.0603 - accuracy: 0.9714 - val_loss: 0.0128 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 33/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9766
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 653ms/step - loss: 0.0532 - accuracy: 0.9766 - val_loss: 0.0126 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 34/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 663ms/step - loss: 0.0657 - accuracy: 0.9656 - val_loss: 0.0282 - val_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 35/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9708
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 672ms/step - loss: 0.0696 - accuracy: 0.9708 - val_loss: 0.0645 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 36/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9760
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 659ms/step - loss: 0.0604 - accuracy: 0.9760 - val_loss: 0.0299 - val_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 37/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9615
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 684ms/step - loss: 0.0729 - accuracy: 0.9615 - val_loss: 0.0205 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 38/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 683ms/step - loss: 0.0605 - accuracy: 0.9750 - val_loss: 0.0101 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 39/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9740
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 65s 1s/step - loss: 0.0541 - accuracy: 0.9740 - val_loss: 0.0119 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 40/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9667
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 47s 783ms/step - loss: 0.0709 - accuracy: 0.9667 - val_loss: 0.0214 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 41/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9703
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 43s 714ms/step - loss: 0.0641 - accuracy: 0.9703 - val_loss: 0.0196 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 42/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9755
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 653ms/step - loss: 0.0561 - accuracy: 0.9755 - val_loss: 0.0762 - val_accuracy: 0.9812 - lr: 1.0000e-04
# Epoch 43/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9760
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 682ms/step - loss: 0.0579 - accuracy: 0.9760 - val_loss: 0.0143 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 44/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9760
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 42s 692ms/step - loss: 0.0497 - accuracy: 0.9760 - val_loss: 0.0107 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 45/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 43s 712ms/step - loss: 0.0513 - accuracy: 0.9750 - val_loss: 0.0090 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 46/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9745
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 659ms/step - loss: 0.0556 - accuracy: 0.9745 - val_loss: 0.0217 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 47/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9708
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 654ms/step - loss: 0.0659 - accuracy: 0.9708 - val_loss: 0.0864 - val_accuracy: 0.9708 - lr: 1.0000e-04
# Epoch 48/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9714
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 41s 687ms/step - loss: 0.0573 - accuracy: 0.9714 - val_loss: 0.0054 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 49/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9776
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 656ms/step - loss: 0.0470 - accuracy: 0.9776 - val_loss: 0.0541 - val_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 50/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9734
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 665ms/step - loss: 0.0548 - accuracy: 0.9734 - val_loss: 0.0134 - val_accuracy: 0.9937 - lr: 1.0000e-04

# %%
Y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['EarlyBlight', 'LateBlight','Healthy']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# 20/20 [==============================] - 5s 240ms/step
# Confusion matrix, without normalization
# [[205   0   1]
#  [  0 200   0]
#  [  2   0 203]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('MultiNet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,51))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 51, 4))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 51, 4))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['EarlyBlight', 'LateBlight', 'Healthy']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# 20/20 [==============================] - 3s 162ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#  EarlyBlight       0.99      1.00      0.99       206
#   LateBlight       1.00      1.00      1.00       200
#      Healthy       1.00      0.99      0.99       205
#
#     accuracy                           1.00       611
#    macro avg       1.00      1.00      1.00       611
# weighted avg       1.00      1.00      1.00       611

# %%
pred=model.predict(X_test)
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
    precision_score,
    recall_score,
    mean_squared_error,
    mean_absolute_error
)

Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)

accuray = accuracy_score(Y_pred, y_test)
f1 = f1_score(Y_pred, y_test, average="weighted")
precision = precision_score(Y_pred, y_test, average='weighted')
recall = recall_score(Y_pred, y_test, average='weighted')
mse = mean_squared_error(Y_pred, y_test)
mae = mean_absolute_error(Y_pred, y_test)

print("VGG19")
print("Accuracy:", accuray)
print("F1 Score:", f1)
print("precision:", precision)
print("recall:", recall)
print("MSE:", mse)
print("MAE:", mae)
# Out:
# 20/20 [==============================] - 3s 164ms/step
# VGG19
# Accuracy: 0.9950900163666121
# F1 Score: 0.9950900745014787
# precision: 0.9950980388357267
# recall: 0.9950900163666121
# MSE: 0.019639934533551555
# MAE: 0.009819967266775777

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
Y_test=np.argmax(Y_test,1)
# Out:
# 20/20 [==============================] - 3s 167ms/step

# %%
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_pred, pos_label=2)
auc=metrics.auc(fpr, tpr)
auc
# Out:
# 0.9914874444310945

# %%
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
