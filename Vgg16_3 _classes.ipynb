# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
from keras.applications.mobilenet import MobileNet
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.applications.resnet50 import ResNet50
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import argparse


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)

        img = cv2.imread(PATH)

        img = cv2.resize(img, (RESIZE,RESIZE))

        IMG.append(np.array(img))
    return IMG

# %%
#load data
early_blight_norm_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/EarlyBlight_Normal',224))
#early_blight_serious_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/EarlyBlight_Serious',224))
late_blight_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/LateBlight',224))
healthy_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Healthy',224))
#insect_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Insect',224))
#lrv_train = np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/LeafRoll',224))
#virus_train =np.array(Dataset_loader('/content/drive/My Drive/potato1/train1/Virus',224))

early_blight_norm_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/EarlyBlight_Normal',224))
#early_blight_serious_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/EarlyBlight_Serious',224))
late_blight_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/LateBlight',224))
healthy_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Healthy',224))
#insect_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Insect',224))
#lrv_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/LeafRoll',224))
#virus_test = np.array(Dataset_loader('/content/drive/My Drive/potato1/test1/Virus',224))
# Out:
# 100%|██████████| 800/800 [00:11<00:00, 66.73it/s]
# 100%|██████████| 800/800 [00:11<00:00, 66.71it/s]
# 100%|██████████| 800/800 [00:13<00:00, 61.41it/s]
# 100%|██████████| 206/206 [00:05<00:00, 36.41it/s]
# 100%|██████████| 200/200 [00:02<00:00, 76.18it/s]
# 100%|██████████| 205/205 [00:03<00:00, 60.75it/s]

# %%
# Create labels
early_blight_norm_train_label = np.full(len(early_blight_norm_train),0)
#early_blight_serious_train_label = np.full(len(early_blight_serious_train),1)
late_blight_train_label = np.full(len(late_blight_train),1)
healthy_train_label = np.full(len(healthy_train),2)
#insect_train_label = np.full(len(insect_train),4)
#lrv_train_label = np.full(len(lrv_train),5)
#virus_train_label = np.full(len(virus_train),6)

early_blight_norm_test_label = np.full(len(early_blight_norm_test),0)
#early_blight_serious_test_label = np.full(len(early_blight_serious_test),1)
late_blight_test_label = np.full(len(late_blight_test),1)
healthy_test_label = np.full(len(healthy_test),2)
#insect_test_label = np.full(len(insect_test),4)
#lrv_test_label = np.full(len(lrv_test),5)
#virus_test_label = np.full(len(virus_test),6)

# %%
# Merge data
X_train = np.concatenate((early_blight_norm_train, late_blight_train, healthy_train), axis = 0)
Y_train = np.concatenate((early_blight_norm_train_label, late_blight_train_label, healthy_train_label), axis = 0)
X_test = np.concatenate((early_blight_norm_test, late_blight_test, healthy_test), axis = 0)
Y_test = np.concatenate((early_blight_norm_test_label, late_blight_test_label, healthy_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 3)
Y_test = to_categorical(Y_test, num_classes= 3)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train,
    test_size=0.2,
    random_state=11
)

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.4,
        height_shift_range=0.4,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images

    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)

vgg      = VGG16(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
outputs = Concatenate(axis=-1)([GlobalAveragePooling2D()(vgg)])
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs)
outputs = Dense(128,activation='relu')(outputs)
outputs = Dropout(0.2)(outputs)
outputs = BatchNormalization()(outputs)
outputs = Dense(3, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  concatenate (Concatenate)   (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense (Dense)               (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 14783299 (56.39 MB)
# Trainable params: 14782019 (56.39 MB)
# Non-trainable params: 1280 (5.00 KB)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/My Drive/Vgg16(3_classes).hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# Epoch 1/50
# 60/60 [==============================] - ETA: 0s - loss: 0.6815 - accuracy: 0.5443
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 82s 871ms/step - loss: 0.6815 - accuracy: 0.5443 - val_loss: 0.5051 - val_accuracy: 0.6729 - lr: 1.0000e-04
# Epoch 2/50
# 60/60 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.7563
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 49s 809ms/step - loss: 0.4533 - accuracy: 0.7563 - val_loss: 0.6416 - val_accuracy: 0.6687 - lr: 1.0000e-04
# Epoch 3/50
# 60/60 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.8651
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 617ms/step - loss: 0.3154 - accuracy: 0.8651 - val_loss: 0.1048 - val_accuracy: 0.9688 - lr: 1.0000e-04
# Epoch 4/50
# 60/60 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9115
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 620ms/step - loss: 0.2185 - accuracy: 0.9115 - val_loss: 0.0729 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 5/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9292
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 629ms/step - loss: 0.1753 - accuracy: 0.9292 - val_loss: 0.1010 - val_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 6/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9365
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 620ms/step - loss: 0.1532 - accuracy: 0.9365 - val_loss: 0.0650 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 7/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9484
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 624ms/step - loss: 0.1262 - accuracy: 0.9484 - val_loss: 0.0391 - val_accuracy: 0.9917 - lr: 1.0000e-04
# Epoch 8/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9641
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 623ms/step - loss: 0.1059 - accuracy: 0.9641 - val_loss: 0.0726 - val_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 9/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9615
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 626ms/step - loss: 0.0970 - accuracy: 0.9615 - val_loss: 0.0341 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 10/50
# 60/60 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9578
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 608ms/step - loss: 0.1000 - accuracy: 0.9578 - val_loss: 0.0214 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 11/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9609
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 623ms/step - loss: 0.0986 - accuracy: 0.9609 - val_loss: 0.0066 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 12/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9677
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0787 - accuracy: 0.9677 - val_loss: 0.0152 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 13/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9578
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 617ms/step - loss: 0.0965 - accuracy: 0.9578 - val_loss: 0.0116 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 14/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9693
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 607ms/step - loss: 0.0816 - accuracy: 0.9693 - val_loss: 0.0322 - val_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 15/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9708
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 632ms/step - loss: 0.0678 - accuracy: 0.9708 - val_loss: 0.0104 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 16/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9578
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 606ms/step - loss: 0.0860 - accuracy: 0.9578 - val_loss: 0.0141 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 17/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 607ms/step - loss: 0.0738 - accuracy: 0.9656 - val_loss: 0.0162 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 18/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9688
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0703 - accuracy: 0.9688 - val_loss: 0.0139 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 19/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9672
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 607ms/step - loss: 0.0764 - accuracy: 0.9672 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 20/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9698
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 626ms/step - loss: 0.0671 - accuracy: 0.9698 - val_loss: 0.0129 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 21/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9714
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 619ms/step - loss: 0.0708 - accuracy: 0.9714 - val_loss: 0.0108 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 22/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9594
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 36s 605ms/step - loss: 0.0786 - accuracy: 0.9594 - val_loss: 0.0100 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 23/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9599
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0902 - accuracy: 0.9599 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 24/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9677
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 613ms/step - loss: 0.0720 - accuracy: 0.9677 - val_loss: 0.0227 - val_accuracy: 0.9937 - lr: 1.0000e-04
# Epoch 25/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9693
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 606ms/step - loss: 0.0667 - accuracy: 0.9693 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 26/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9719
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 607ms/step - loss: 0.0599 - accuracy: 0.9719 - val_loss: 0.0055 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 27/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9672
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 614ms/step - loss: 0.0715 - accuracy: 0.9672 - val_loss: 0.0051 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 28/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9682
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 617ms/step - loss: 0.0622 - accuracy: 0.9682 - val_loss: 0.0126 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 29/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9745
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 620ms/step - loss: 0.0545 - accuracy: 0.9745 - val_loss: 0.0109 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 30/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9625
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 36s 601ms/step - loss: 0.0742 - accuracy: 0.9625 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 31/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9740
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 36s 603ms/step - loss: 0.0574 - accuracy: 0.9740 - val_loss: 0.0068 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 32/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9771
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0554 - accuracy: 0.9771 - val_loss: 0.0085 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 33/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9729
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 632ms/step - loss: 0.0570 - accuracy: 0.9729 - val_loss: 0.0053 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 34/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9729
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 632ms/step - loss: 0.0537 - accuracy: 0.9729 - val_loss: 0.0042 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 35/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9620
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 620ms/step - loss: 0.0749 - accuracy: 0.9620 - val_loss: 0.0055 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 36/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9688
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 642ms/step - loss: 0.0668 - accuracy: 0.9688 - val_loss: 0.0145 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 37/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9708
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 37s 622ms/step - loss: 0.0549 - accuracy: 0.9708 - val_loss: 0.0117 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 38/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9703
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 655ms/step - loss: 0.0582 - accuracy: 0.9703 - val_loss: 0.0050 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 39/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9755
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0513 - accuracy: 0.9755 - val_loss: 0.0052 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 40/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9719
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 658ms/step - loss: 0.0543 - accuracy: 0.9719 - val_loss: 0.0130 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 41/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9771
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 625ms/step - loss: 0.0591 - accuracy: 0.9771 - val_loss: 0.0090 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 42/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9693
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 645ms/step - loss: 0.0640 - accuracy: 0.9693 - val_loss: 0.0119 - val_accuracy: 0.9958 - lr: 1.0000e-04
# Epoch 43/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9724
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 633ms/step - loss: 0.0588 - accuracy: 0.9724 - val_loss: 0.0050 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 44/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9776
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 635ms/step - loss: 0.0476 - accuracy: 0.9776 - val_loss: 0.0078 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 45/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9776
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 646ms/step - loss: 0.0456 - accuracy: 0.9776 - val_loss: 0.0356 - val_accuracy: 0.9896 - lr: 1.0000e-04
# Epoch 46/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9781
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 635ms/step - loss: 0.0519 - accuracy: 0.9781 - val_loss: 0.0029 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 47/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9719
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 654ms/step - loss: 0.0560 - accuracy: 0.9719 - val_loss: 0.0054 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 48/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9703
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 39s 645ms/step - loss: 0.0614 - accuracy: 0.9703 - val_loss: 0.0059 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 49/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9771
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 40s 659ms/step - loss: 0.0501 - accuracy: 0.9771 - val_loss: 0.0035 - val_accuracy: 0.9979 - lr: 1.0000e-04
# Epoch 50/50
# 60/60 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9771
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 60/60 [==============================] - 38s 624ms/step - loss: 0.0487 - accuracy: 0.9771 - val_loss: 0.0058 - val_accuracy: 1.0000 - lr: 1.0000e-04

# %%
Y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['EarlyBlight', 'LateBlight','Healthy']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# 20/20 [==============================] - 4s 208ms/step
# Confusion matrix, without normalization
# [[205   0   1]
#  [  0 199   1]
#  [  1   0 204]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('MultiNet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,51))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 51, 4))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 51, 4))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['EarlyBlight', 'LateBlight', 'Healthy']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# 20/20 [==============================] - 2s 128ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#  EarlyBlight       1.00      1.00      1.00       206
#   LateBlight       1.00      0.99      1.00       200
#      Healthy       0.99      1.00      0.99       205
#
#     accuracy                           1.00       611
#    macro avg       1.00      1.00      1.00       611
# weighted avg       1.00      1.00      1.00       611

# %%
pred=model.predict(X_test)
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
    precision_score,
    recall_score,
    mean_squared_error,
    mean_absolute_error
)

Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)

accuray = accuracy_score(Y_pred, y_test)
f1 = f1_score(Y_pred, y_test, average="weighted")
precision = precision_score(Y_pred, y_test, average='weighted')
recall = recall_score(Y_pred, y_test, average='weighted')
mse = mean_squared_error(Y_pred, y_test)
mae = mean_absolute_error(Y_pred, y_test)

print("VGG16")
print("Accuracy:", accuray)
print("F1 Score:", f1)
print("precision:", precision)
print("recall:", recall)
print("MSE:", mse)
print("MAE:", mae)
# Out:
# 20/20 [==============================] - 2s 126ms/step
# VGG16
# Accuracy: 0.9950900163666121
# F1 Score: 0.9950860941044117
# precision: 0.9950902159594427
# recall: 0.9950900163666121
# MSE: 0.014729950900163666
# MAE: 0.008183306055646482

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
Y_test=np.argmax(Y_test,1)
# Out:
# 20/20 [==============================] - 2s 126ms/step

# %%
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_pred, pos_label=2)
auc=metrics.auc(fpr, tpr)
auc
# Out:
# 0.9939024390243902

# %%
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
